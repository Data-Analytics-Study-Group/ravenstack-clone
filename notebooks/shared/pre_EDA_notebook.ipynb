# %%
import sys
from pathlib import Path

# ---------------------------------------------------
# Ensure project root is in Python path (important for notebooks in subfolders)
# ---------------------------------------------------
PROJECT_ROOT = Path().resolve().parents[1]
sys.path.append(str(PROJECT_ROOT))

# ---------------------------------------------------
# Standard imports
# ---------------------------------------------------
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os 
import warnings

# ignore warning
warnings.filterwarnings("ignore")

# make sure printed values are not truncated
pd.set_option('display.max_rows', None)

# get root anchor
from src.config import PROCESSED_DIR, RAW_DIR

# %%
# load the dataframes from the clean csv files 
#accounts = pd.read_csv("../data/processed/processed_account.csv")

#-- the above line defining pathe to csv using relative path has been commented out.
#-- instead, use the predefined PROCESSED_DIR to access from root to avoid broken paths
#-- csv filename was also corrected to point to the correct file
accounts = pd.read_csv(PROCESSED_DIR / "processed_feature_usage.csv")
accounts.head()
# Out:
#   subscription_id  usage_date feature_name  usage_count  usage_duration_secs  \
# 0        S-0fcf7d  2023-07-27   feature_20            9                 5004
# 1        S-c25263  2023-08-07    feature_5            9                  369
# 2        S-f29e7f  2023-12-07    feature_3            9                 1458
# 3        S-be655e  2024-07-28   feature_40            5                 2085
# 4        S-f9b1d0  2024-12-02   feature_12           12                  900
#
#    error_count  is_beta_feature  row_id
# 0            0            False       0
# 1            0            False       1
# 2            0            False       2
# 3            0            False       3
# 4            0            False       4
